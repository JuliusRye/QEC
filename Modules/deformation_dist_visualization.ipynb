# %%
import sys, os
sys.path.append(os.path.abspath(
    os.getcwd()+"/core")
)

# %%
from core.neural_network import load_params
import matplotlib.pyplot as plt
from jax import nn
import jax.numpy as jnp

# %%
probs3 = nn.softmax(load_params("data/CNN-B-3.json")[1]["deformation_dist"], axis=0)
probs5 = nn.softmax(load_params("data/CNN-B-5.json")[1]["deformation_dist"], axis=0)
probs7 = nn.softmax(load_params("data/CNN-B-7.json")[1]["deformation_dist"], axis=0)
probs9 = nn.softmax(load_params("data/CNN-B-9.json")[1]["deformation_dist"], axis=0)
probability = [probs3, probs5, probs7, probs9]

# %%
colors = [
    "#FFFFFF",  # I
    "#88C946",  # X <-> Y
    "#C43119",  # Y <-> Z
    "#00ADE7",  # X <-> Z
    "#833794",  # X -> Z -> Y -> X
    "#FFB94C",  # X -> Y -> Z -> X
]

# %%
figure, axs = plt.subplots(4, 6, figsize=(6, 4), dpi=300)
# figure.suptitle("Data qubit deformations", fontsize=16)
for i in range(4):
    for j in range(6):
        im = axs[i, j].imshow(probability[i][j], cmap='hot', interpolation='nearest', vmin=0, vmax=max(p.max() for p in probability), origin='lower')
        axs[i, j].set_xticks(jnp.arange(2*i+4)-.5)
        axs[i, j].set_yticks(jnp.arange(2*i+4)-.5)
        axs[i, j].set_xticklabels([])
        axs[i, j].set_yticklabels([])
        # axs[i, j].grid(visible=True, lw=.5)
        if i == 0:
            axs[i, j].set_title(
                " ", 
                fontsize=12, 
                color=colors[j], 
                fontweight="bold", 
                bbox=dict(boxstyle="circle", edgecolor="black", facecolor=colors[j]),
                pad=10  # Adjust the padding to lift the title up slightly
            )
        # if i == 3:
        #     axs[i, j].set_xlabel(f"D={j}", fontsize=12)
        if j == 0:
            axs[i, j].set_ylabel(f"L={3 + 2*i}", fontsize=12)
cax = figure.add_axes([0.92, 0.1, 0.03, 0.8])
cbar = plt.colorbar(im, cax=cax)
cbar.set_label("Probability of deformation on data qubit", fontsize=12)
# cbar.ax.set_yticks(jnp.arange(0, 2/6, .03))
cbar.ax.set_yticklabels(["{:.0%}".format(i) for i in cbar.get_ticks()])

plt.savefig("figs/CNN-B-deformation_dist.eps", bbox_inches='tight', dpi=300)
plt.savefig("figs/CNN-B-deformation_dist.png", bbox_inches='tight', dpi=300)

plt.show()
# Out:
# /tmp/ipykernel_722090/298668071.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels(["{:.0%}".format(i) for i in cbar.get_ticks()])

# %%
figure, axs = plt.subplots(4, 3, figsize=(6, 4), dpi=300)
# figure.suptitle("Data qubit deformations", fontsize=16)
groups = [(0,1),(2,5),(3,4)]
colors_ = [colors[0], colors[2], colors[3]]
for i in range(4):
    for j in range(3):
        im = axs[i, j].imshow(probability[i][groups[j][0]] + probability[i][groups[j][1]], cmap='hot', interpolation='nearest', vmin=0, vmax=1, origin='lower')
        axs[i, j].set_xticks(jnp.arange(2*i+4)-.5)
        axs[i, j].set_yticks(jnp.arange(2*i+4)-.5)
        axs[i, j].set_xticklabels([])
        axs[i, j].set_yticklabels([])
        # axs[i, j].grid(visible=True, lw=.5)
        if i == 0:
            axs[i, j].set_title(
                " ", 
                fontsize=12, 
                color=colors[j], 
                fontweight="bold", 
                bbox=dict(boxstyle="circle", edgecolor="black", facecolor=colors_[j]),
                pad=10  # Adjust the padding to lift the title up slightly
            )
        # if i == 3:
        #     axs[i, j].set_xlabel(f"D={j}", fontsize=12)
        if j == 0:
            axs[i, j].set_ylabel(f"L={3 + 2*i}", fontsize=12)
cax = figure.add_axes([0.92, 0.1, 0.03, 0.8])
cbar = plt.colorbar(im, cax=cax)
cbar.set_label("Probability of deformation on data qubit", fontsize=12)
# cbar.ax.set_yticks(jnp.arange(0, 2/6, .03))
cbar.ax.set_yticklabels(["{:.0%}".format(i) for i in cbar.get_ticks()])

# plt.savefig("figs/CNN-B-deformation_dist.eps", bbox_inches='tight', dpi=300)
# plt.savefig("figs/CNN-B-deformation_dist.png", bbox_inches='tight', dpi=300)

plt.show()
# Out:
# /tmp/ipykernel_722090/2917351637.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels(["{:.0%}".format(i) for i in cbar.get_ticks()])

# %%
from core.quantum_error_correction_code import SurfaceCode

for probs in probability:
    deformation = probs.argmax(axis=0).flatten()
    deformation = jnp.array([0,0,2,3,3,2])[deformation]
    L = probs.shape[1]
    display(L)
    code = SurfaceCode(L)
    parity_info = code.deformation_parity_info(deformation)
    print(code.show_latex_code(parity_info, deformation))
# Out:
# 3
# % Draw the plaquettes
# \filldraw[fill=black!10, draw=none] (0,0) -- (2,0) -- (2,2) -- (0,2) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,2) -- (2,2) -- (2,4) -- (0,4) -- cycle;
# \filldraw[fill=black!5, draw=none] (2,0) -- (4,0) -- (4,2) -- (2,2) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,2) -- (4,2) -- (4,4) -- (2,4) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,0) -- (0,2) -- (-1,1) -- cycle;
# \filldraw[fill=black!5, draw=none] (4,2) -- (4,4) -- (5,3) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,0) -- (4,0) -- (3,-1) -- cycle;
# \filldraw[fill=black!10, draw=none] (0,4) -- (2,4) -- (1,5) -- cycle;
#
# % Draw the data qubits
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D0) at (0.0,0.0) {};
# \node[draw, circle, fill=BrickRed, line width=.5mm, minimum size=5mm] (D1) at (2.0,0.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D2) at (4.0,0.0) {};
# \node[draw, circle, fill=BrickRed, line width=.5mm, minimum size=5mm] (D3) at (0.0,2.0) {};
# \node[draw, circle, fill=BrickRed, line width=.5mm, minimum size=5mm] (D4) at (2.0,2.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D5) at (4.0,2.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D6) at (0.0,4.0) {};
# \node[draw, circle, fill=BrickRed, line width=.5mm, minimum size=5mm] (D7) at (2.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D8) at (4.0,4.0) {};
#
# % Draw the syndrome qubits
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S0) at (3.0,-1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S1) at (-1.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S2) at (1.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S3) at (3.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S4) at (1.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S5) at (3.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S6) at (5.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S7) at (1.0,5.0) {};
#
# % Draw the x stabilizers
# \draw[red!80, line width=.3mm] (S0) -- (D1);
# \draw[red!80, line width=.3mm] (S0) -- (D2);
# \draw[red!80, line width=.3mm] (S1) -- (D0);
# \draw[red!80, line width=.3mm] (S2) -- (D1);
# \draw[red!80, line width=.3mm] (S2) -- (D3);
# \draw[red!80, line width=.3mm] (S2) -- (D4);
# \draw[red!80, line width=.3mm] (S5) -- (D4);
# \draw[red!80, line width=.3mm] (S5) -- (D5);
# \draw[red!80, line width=.3mm] (S5) -- (D7);
# \draw[red!80, line width=.3mm] (S5) -- (D8);
# \draw[red!80, line width=.3mm] (S7) -- (D6);
# \draw[red!80, line width=.3mm] (S7) -- (D7);
#
# % Draw the y stabilizers
# \draw[green!80, line width=.3mm] (S1) -- (D3);
# \draw[green!80, line width=.3mm] (S3) -- (D1);
# \draw[green!80, line width=.3mm] (S3) -- (D4);
# \draw[green!80, line width=.3mm] (S4) -- (D3);
# \draw[green!80, line width=.3mm] (S4) -- (D4);
# \draw[green!80, line width=.3mm] (S4) -- (D7);
#
# % Draw the z stabilizers
# \draw[Cyan, line width=.3mm] (S2) -- (D0);
# \draw[Cyan, line width=.3mm] (S3) -- (D2);
# \draw[Cyan, line width=.3mm] (S3) -- (D5);
# \draw[Cyan, line width=.3mm] (S4) -- (D6);
# \draw[Cyan, line width=.3mm] (S6) -- (D5);
# \draw[Cyan, line width=.3mm] (S6) -- (D8);
# 5
# % Draw the plaquettes
# \filldraw[fill=black!10, draw=none] (0,0) -- (2,0) -- (2,2) -- (0,2) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,2) -- (2,2) -- (2,4) -- (0,4) -- cycle;
# \filldraw[fill=black!10, draw=none] (0,4) -- (2,4) -- (2,6) -- (0,6) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,6) -- (2,6) -- (2,8) -- (0,8) -- cycle;
# \filldraw[fill=black!5, draw=none] (2,0) -- (4,0) -- (4,2) -- (2,2) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,2) -- (4,2) -- (4,4) -- (2,4) -- cycle;
# \filldraw[fill=black!5, draw=none] (2,4) -- (4,4) -- (4,6) -- (2,6) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,6) -- (4,6) -- (4,8) -- (2,8) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,0) -- (6,0) -- (6,2) -- (4,2) -- cycle;
# \filldraw[fill=black!5, draw=none] (4,2) -- (6,2) -- (6,4) -- (4,4) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,4) -- (6,4) -- (6,6) -- (4,6) -- cycle;
# \filldraw[fill=black!5, draw=none] (4,6) -- (6,6) -- (6,8) -- (4,8) -- cycle;
# \filldraw[fill=black!5, draw=none] (6,0) -- (8,0) -- (8,2) -- (6,2) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,2) -- (8,2) -- (8,4) -- (6,4) -- cycle;
# \filldraw[fill=black!5, draw=none] (6,4) -- (8,4) -- (8,6) -- (6,6) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,6) -- (8,6) -- (8,8) -- (6,8) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,0) -- (0,2) -- (-1,1) -- cycle;
# \filldraw[fill=black!5, draw=none] (8,2) -- (8,4) -- (9,3) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,0) -- (4,0) -- (3,-1) -- cycle;
# \filldraw[fill=black!10, draw=none] (0,8) -- (2,8) -- (1,9) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,4) -- (0,6) -- (-1,5) -- cycle;
# \filldraw[fill=black!5, draw=none] (8,6) -- (8,8) -- (9,7) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,0) -- (8,0) -- (7,-1) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,8) -- (6,8) -- (5,9) -- cycle;
#
# % Draw the data qubits
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D0) at (0.0,0.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D1) at (2.0,0.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D2) at (4.0,0.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D3) at (6.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D4) at (8.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D5) at (0.0,2.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D6) at (2.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D7) at (4.0,2.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D8) at (6.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D9) at (8.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D10) at (0.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D11) at (2.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D12) at (4.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D13) at (6.0,4.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D14) at (8.0,4.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D15) at (0.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D16) at (2.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D17) at (4.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D18) at (6.0,6.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D19) at (8.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D20) at (0.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D21) at (2.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D22) at (4.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D23) at (6.0,8.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D24) at (8.0,8.0) {};
#
# % Draw the syndrome qubits
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S0) at (3.0,-1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S1) at (7.0,-1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S2) at (-1.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S3) at (1.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S4) at (3.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S5) at (5.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S6) at (7.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S7) at (1.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S8) at (3.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S9) at (5.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S10) at (7.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S11) at (9.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S12) at (-1.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S13) at (1.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S14) at (3.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S15) at (5.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S16) at (7.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S17) at (1.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S18) at (3.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S19) at (5.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S20) at (7.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S21) at (9.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S22) at (1.0,9.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S23) at (5.0,9.0) {};
#
# % Draw the x stabilizers
# \draw[red!80, line width=.3mm] (S0) -- (D1);
# \draw[red!80, line width=.3mm] (S0) -- (D2);
# \draw[red!80, line width=.3mm] (S1) -- (D3);
# \draw[red!80, line width=.3mm] (S2) -- (D0);
# \draw[red!80, line width=.3mm] (S2) -- (D5);
# \draw[red!80, line width=.3mm] (S3) -- (D1);
# \draw[red!80, line width=.3mm] (S3) -- (D6);
# \draw[red!80, line width=.3mm] (S4) -- (D7);
# \draw[red!80, line width=.3mm] (S5) -- (D2);
# \draw[red!80, line width=.3mm] (S5) -- (D3);
# \draw[red!80, line width=.3mm] (S5) -- (D8);
# \draw[red!80, line width=.3mm] (S6) -- (D4);
# \draw[red!80, line width=.3mm] (S6) -- (D9);
# \draw[red!80, line width=.3mm] (S7) -- (D5);
# \draw[red!80, line width=.3mm] (S7) -- (D10);
# \draw[red!80, line width=.3mm] (S8) -- (D6);
# \draw[red!80, line width=.3mm] (S8) -- (D11);
# \draw[red!80, line width=.3mm] (S8) -- (D12);
# \draw[red!80, line width=.3mm] (S9) -- (D7);
# \draw[red!80, line width=.3mm] (S10) -- (D8);
# \draw[red!80, line width=.3mm] (S10) -- (D13);
# \draw[red!80, line width=.3mm] (S11) -- (D9);
# \draw[red!80, line width=.3mm] (S11) -- (D14);
# \draw[red!80, line width=.3mm] (S12) -- (D10);
# \draw[red!80, line width=.3mm] (S12) -- (D15);
# \draw[red!80, line width=.3mm] (S13) -- (D11);
# \draw[red!80, line width=.3mm] (S13) -- (D16);
# \draw[red!80, line width=.3mm] (S15) -- (D12);
# \draw[red!80, line width=.3mm] (S15) -- (D13);
# \draw[red!80, line width=.3mm] (S15) -- (D17);
# \draw[red!80, line width=.3mm] (S15) -- (D18);
# \draw[red!80, line width=.3mm] (S16) -- (D14);
# \draw[red!80, line width=.3mm] (S16) -- (D19);
# \draw[red!80, line width=.3mm] (S17) -- (D15);
# \draw[red!80, line width=.3mm] (S18) -- (D16);
# \draw[red!80, line width=.3mm] (S18) -- (D17);
# \draw[red!80, line width=.3mm] (S18) -- (D21);
# \draw[red!80, line width=.3mm] (S18) -- (D22);
# \draw[red!80, line width=.3mm] (S20) -- (D18);
# \draw[red!80, line width=.3mm] (S20) -- (D23);
# \draw[red!80, line width=.3mm] (S21) -- (D19);
# \draw[red!80, line width=.3mm] (S21) -- (D24);
# \draw[red!80, line width=.3mm] (S22) -- (D20);
# \draw[red!80, line width=.3mm] (S22) -- (D21);
# \draw[red!80, line width=.3mm] (S23) -- (D22);
# \draw[red!80, line width=.3mm] (S23) -- (D23);
#
# % Draw the y stabilizers
#
# % Draw the z stabilizers
# \draw[Cyan, line width=.3mm] (S1) -- (D4);
# \draw[Cyan, line width=.3mm] (S3) -- (D0);
# \draw[Cyan, line width=.3mm] (S3) -- (D5);
# \draw[Cyan, line width=.3mm] (S4) -- (D1);
# \draw[Cyan, line width=.3mm] (S4) -- (D2);
# \draw[Cyan, line width=.3mm] (S4) -- (D6);
# \draw[Cyan, line width=.3mm] (S5) -- (D7);
# \draw[Cyan, line width=.3mm] (S6) -- (D3);
# \draw[Cyan, line width=.3mm] (S6) -- (D8);
# \draw[Cyan, line width=.3mm] (S7) -- (D6);
# \draw[Cyan, line width=.3mm] (S7) -- (D11);
# \draw[Cyan, line width=.3mm] (S8) -- (D7);
# \draw[Cyan, line width=.3mm] (S9) -- (D8);
# \draw[Cyan, line width=.3mm] (S9) -- (D12);
# \draw[Cyan, line width=.3mm] (S9) -- (D13);
# \draw[Cyan, line width=.3mm] (S10) -- (D9);
# \draw[Cyan, line width=.3mm] (S10) -- (D14);
# \draw[Cyan, line width=.3mm] (S13) -- (D10);
# \draw[Cyan, line width=.3mm] (S13) -- (D15);
# \draw[Cyan, line width=.3mm] (S14) -- (D11);
# \draw[Cyan, line width=.3mm] (S14) -- (D12);
# \draw[Cyan, line width=.3mm] (S14) -- (D16);
# \draw[Cyan, line width=.3mm] (S14) -- (D17);
# \draw[Cyan, line width=.3mm] (S16) -- (D13);
# \draw[Cyan, line width=.3mm] (S16) -- (D18);
# \draw[Cyan, line width=.3mm] (S17) -- (D16);
# \draw[Cyan, line width=.3mm] (S17) -- (D20);
# \draw[Cyan, line width=.3mm] (S17) -- (D21);
# \draw[Cyan, line width=.3mm] (S19) -- (D17);
# \draw[Cyan, line width=.3mm] (S19) -- (D18);
# \draw[Cyan, line width=.3mm] (S19) -- (D22);
# \draw[Cyan, line width=.3mm] (S19) -- (D23);
# \draw[Cyan, line width=.3mm] (S20) -- (D19);
# \draw[Cyan, line width=.3mm] (S20) -- (D24);
# 7
# % Draw the plaquettes
# \filldraw[fill=black!10, draw=none] (0,0) -- (2,0) -- (2,2) -- (0,2) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,2) -- (2,2) -- (2,4) -- (0,4) -- cycle;
# \filldraw[fill=black!10, draw=none] (0,4) -- (2,4) -- (2,6) -- (0,6) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,6) -- (2,6) -- (2,8) -- (0,8) -- cycle;
# \filldraw[fill=black!10, draw=none] (0,8) -- (2,8) -- (2,10) -- (0,10) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,10) -- (2,10) -- (2,12) -- (0,12) -- cycle;
# \filldraw[fill=black!5, draw=none] (2,0) -- (4,0) -- (4,2) -- (2,2) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,2) -- (4,2) -- (4,4) -- (2,4) -- cycle;
# \filldraw[fill=black!5, draw=none] (2,4) -- (4,4) -- (4,6) -- (2,6) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,6) -- (4,6) -- (4,8) -- (2,8) -- cycle;
# \filldraw[fill=black!5, draw=none] (2,8) -- (4,8) -- (4,10) -- (2,10) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,10) -- (4,10) -- (4,12) -- (2,12) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,0) -- (6,0) -- (6,2) -- (4,2) -- cycle;
# \filldraw[fill=black!5, draw=none] (4,2) -- (6,2) -- (6,4) -- (4,4) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,4) -- (6,4) -- (6,6) -- (4,6) -- cycle;
# \filldraw[fill=black!5, draw=none] (4,6) -- (6,6) -- (6,8) -- (4,8) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,8) -- (6,8) -- (6,10) -- (4,10) -- cycle;
# \filldraw[fill=black!5, draw=none] (4,10) -- (6,10) -- (6,12) -- (4,12) -- cycle;
# \filldraw[fill=black!5, draw=none] (6,0) -- (8,0) -- (8,2) -- (6,2) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,2) -- (8,2) -- (8,4) -- (6,4) -- cycle;
# \filldraw[fill=black!5, draw=none] (6,4) -- (8,4) -- (8,6) -- (6,6) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,6) -- (8,6) -- (8,8) -- (6,8) -- cycle;
# \filldraw[fill=black!5, draw=none] (6,8) -- (8,8) -- (8,10) -- (6,10) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,10) -- (8,10) -- (8,12) -- (6,12) -- cycle;
# \filldraw[fill=black!10, draw=none] (8,0) -- (10,0) -- (10,2) -- (8,2) -- cycle;
# \filldraw[fill=black!5, draw=none] (8,2) -- (10,2) -- (10,4) -- (8,4) -- cycle;
# \filldraw[fill=black!10, draw=none] (8,4) -- (10,4) -- (10,6) -- (8,6) -- cycle;
# \filldraw[fill=black!5, draw=none] (8,6) -- (10,6) -- (10,8) -- (8,8) -- cycle;
# \filldraw[fill=black!10, draw=none] (8,8) -- (10,8) -- (10,10) -- (8,10) -- cycle;
# \filldraw[fill=black!5, draw=none] (8,10) -- (10,10) -- (10,12) -- (8,12) -- cycle;
# \filldraw[fill=black!5, draw=none] (10,0) -- (12,0) -- (12,2) -- (10,2) -- cycle;
# \filldraw[fill=black!10, draw=none] (10,2) -- (12,2) -- (12,4) -- (10,4) -- cycle;
# \filldraw[fill=black!5, draw=none] (10,4) -- (12,4) -- (12,6) -- (10,6) -- cycle;
# \filldraw[fill=black!10, draw=none] (10,6) -- (12,6) -- (12,8) -- (10,8) -- cycle;
# \filldraw[fill=black!5, draw=none] (10,8) -- (12,8) -- (12,10) -- (10,10) -- cycle;
# \filldraw[fill=black!10, draw=none] (10,10) -- (12,10) -- (12,12) -- (10,12) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,0) -- (0,2) -- (-1,1) -- cycle;
# \filldraw[fill=black!5, draw=none] (12,2) -- (12,4) -- (13,3) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,0) -- (4,0) -- (3,-1) -- cycle;
# \filldraw[fill=black!10, draw=none] (0,12) -- (2,12) -- (1,13) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,4) -- (0,6) -- (-1,5) -- cycle;
# \filldraw[fill=black!5, draw=none] (12,6) -- (12,8) -- (13,7) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,0) -- (8,0) -- (7,-1) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,12) -- (6,12) -- (5,13) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,8) -- (0,10) -- (-1,9) -- cycle;
# \filldraw[fill=black!5, draw=none] (12,10) -- (12,12) -- (13,11) -- cycle;
# \filldraw[fill=black!10, draw=none] (10,0) -- (12,0) -- (11,-1) -- cycle;
# \filldraw[fill=black!10, draw=none] (8,12) -- (10,12) -- (9,13) -- cycle;
#
# % Draw the data qubits
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D0) at (0.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D1) at (2.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D2) at (4.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D3) at (6.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D4) at (8.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D5) at (10.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D6) at (12.0,0.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D7) at (0.0,2.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D8) at (2.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D9) at (4.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D10) at (6.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D11) at (8.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D12) at (10.0,2.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D13) at (12.0,2.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D14) at (0.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D15) at (2.0,4.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D16) at (4.0,4.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D17) at (6.0,4.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D18) at (8.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D19) at (10.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D20) at (12.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D21) at (0.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D22) at (2.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D23) at (4.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D24) at (6.0,6.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D25) at (8.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D26) at (10.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D27) at (12.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D28) at (0.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D29) at (2.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D30) at (4.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D31) at (6.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D32) at (8.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D33) at (10.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D34) at (12.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D35) at (0.0,10.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D36) at (2.0,10.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D37) at (4.0,10.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D38) at (6.0,10.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D39) at (8.0,10.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D40) at (10.0,10.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D41) at (12.0,10.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D42) at (0.0,12.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D43) at (2.0,12.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D44) at (4.0,12.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D45) at (6.0,12.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D46) at (8.0,12.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D47) at (10.0,12.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D48) at (12.0,12.0) {};
#
# % Draw the syndrome qubits
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S0) at (3.0,-1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S1) at (7.0,-1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S2) at (11.0,-1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S3) at (-1.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S4) at (1.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S5) at (3.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S6) at (5.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S7) at (7.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S8) at (9.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S9) at (11.0,1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S10) at (1.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S11) at (3.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S12) at (5.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S13) at (7.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S14) at (9.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S15) at (11.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S16) at (13.0,3.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S17) at (-1.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S18) at (1.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S19) at (3.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S20) at (5.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S21) at (7.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S22) at (9.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S23) at (11.0,5.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S24) at (1.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S25) at (3.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S26) at (5.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S27) at (7.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S28) at (9.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S29) at (11.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S30) at (13.0,7.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S31) at (-1.0,9.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S32) at (1.0,9.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S33) at (3.0,9.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S34) at (5.0,9.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S35) at (7.0,9.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S36) at (9.0,9.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S37) at (11.0,9.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S38) at (1.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S39) at (3.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S40) at (5.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S41) at (7.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S42) at (9.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S43) at (11.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S44) at (13.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S45) at (1.0,13.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S46) at (5.0,13.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S47) at (9.0,13.0) {};
#
# % Draw the x stabilizers
# \draw[red!80, line width=.3mm] (S4) -- (D0);
# \draw[red!80, line width=.3mm] (S4) -- (D7);
# \draw[red!80, line width=.3mm] (S4) -- (D8);
# \draw[red!80, line width=.3mm] (S5) -- (D1);
# \draw[red!80, line width=.3mm] (S5) -- (D2);
# \draw[red!80, line width=.3mm] (S5) -- (D9);
# \draw[red!80, line width=.3mm] (S7) -- (D3);
# \draw[red!80, line width=.3mm] (S7) -- (D4);
# \draw[red!80, line width=.3mm] (S7) -- (D10);
# \draw[red!80, line width=.3mm] (S7) -- (D11);
# \draw[red!80, line width=.3mm] (S9) -- (D5);
# \draw[red!80, line width=.3mm] (S9) -- (D6);
# \draw[red!80, line width=.3mm] (S9) -- (D12);
# \draw[red!80, line width=.3mm] (S11) -- (D8);
# \draw[red!80, line width=.3mm] (S11) -- (D15);
# \draw[red!80, line width=.3mm] (S12) -- (D9);
# \draw[red!80, line width=.3mm] (S12) -- (D10);
# \draw[red!80, line width=.3mm] (S12) -- (D16);
# \draw[red!80, line width=.3mm] (S12) -- (D17);
# \draw[red!80, line width=.3mm] (S14) -- (D11);
# \draw[red!80, line width=.3mm] (S14) -- (D12);
# \draw[red!80, line width=.3mm] (S14) -- (D18);
# \draw[red!80, line width=.3mm] (S15) -- (D13);
# \draw[red!80, line width=.3mm] (S15) -- (D19);
# \draw[red!80, line width=.3mm] (S15) -- (D20);
# \draw[red!80, line width=.3mm] (S18) -- (D14);
# \draw[red!80, line width=.3mm] (S18) -- (D15);
# \draw[red!80, line width=.3mm] (S18) -- (D21);
# \draw[red!80, line width=.3mm] (S18) -- (D22);
# \draw[red!80, line width=.3mm] (S19) -- (D16);
# \draw[red!80, line width=.3mm] (S20) -- (D23);
# \draw[red!80, line width=.3mm] (S20) -- (D24);
# \draw[red!80, line width=.3mm] (S21) -- (D17);
# \draw[red!80, line width=.3mm] (S21) -- (D18);
# \draw[red!80, line width=.3mm] (S21) -- (D25);
# \draw[red!80, line width=.3mm] (S22) -- (D19);
# \draw[red!80, line width=.3mm] (S22) -- (D26);
# \draw[red!80, line width=.3mm] (S25) -- (D22);
# \draw[red!80, line width=.3mm] (S25) -- (D23);
# \draw[red!80, line width=.3mm] (S25) -- (D29);
# \draw[red!80, line width=.3mm] (S25) -- (D30);
# \draw[red!80, line width=.3mm] (S27) -- (D24);
# \draw[red!80, line width=.3mm] (S27) -- (D31);
# \draw[red!80, line width=.3mm] (S27) -- (D32);
# \draw[red!80, line width=.3mm] (S28) -- (D25);
# \draw[red!80, line width=.3mm] (S29) -- (D26);
# \draw[red!80, line width=.3mm] (S29) -- (D27);
# \draw[red!80, line width=.3mm] (S29) -- (D33);
# \draw[red!80, line width=.3mm] (S29) -- (D34);
# \draw[red!80, line width=.3mm] (S32) -- (D28);
# \draw[red!80, line width=.3mm] (S32) -- (D29);
# \draw[red!80, line width=.3mm] (S32) -- (D35);
# \draw[red!80, line width=.3mm] (S33) -- (D36);
# \draw[red!80, line width=.3mm] (S33) -- (D37);
# \draw[red!80, line width=.3mm] (S34) -- (D30);
# \draw[red!80, line width=.3mm] (S34) -- (D31);
# \draw[red!80, line width=.3mm] (S35) -- (D38);
# \draw[red!80, line width=.3mm] (S36) -- (D32);
# \draw[red!80, line width=.3mm] (S36) -- (D33);
# \draw[red!80, line width=.3mm] (S36) -- (D39);
# \draw[red!80, line width=.3mm] (S36) -- (D40);
# \draw[red!80, line width=.3mm] (S38) -- (D36);
# \draw[red!80, line width=.3mm] (S38) -- (D42);
# \draw[red!80, line width=.3mm] (S38) -- (D43);
# \draw[red!80, line width=.3mm] (S40) -- (D37);
# \draw[red!80, line width=.3mm] (S40) -- (D38);
# \draw[red!80, line width=.3mm] (S40) -- (D44);
# \draw[red!80, line width=.3mm] (S40) -- (D45);
# \draw[red!80, line width=.3mm] (S41) -- (D39);
# \draw[red!80, line width=.3mm] (S42) -- (D46);
# \draw[red!80, line width=.3mm] (S43) -- (D40);
# \draw[red!80, line width=.3mm] (S43) -- (D41);
# \draw[red!80, line width=.3mm] (S43) -- (D47);
# \draw[red!80, line width=.3mm] (S43) -- (D48);
# \draw[red!80, line width=.3mm] (S47) -- (D47);
#
# % Draw the y stabilizers
#
# % Draw the z stabilizers
# \draw[Cyan, line width=.3mm] (S0) -- (D1);
# \draw[Cyan, line width=.3mm] (S0) -- (D2);
# \draw[Cyan, line width=.3mm] (S1) -- (D3);
# \draw[Cyan, line width=.3mm] (S1) -- (D4);
# \draw[Cyan, line width=.3mm] (S2) -- (D5);
# \draw[Cyan, line width=.3mm] (S2) -- (D6);
# \draw[Cyan, line width=.3mm] (S3) -- (D0);
# \draw[Cyan, line width=.3mm] (S3) -- (D7);
# \draw[Cyan, line width=.3mm] (S4) -- (D1);
# \draw[Cyan, line width=.3mm] (S5) -- (D8);
# \draw[Cyan, line width=.3mm] (S6) -- (D2);
# \draw[Cyan, line width=.3mm] (S6) -- (D3);
# \draw[Cyan, line width=.3mm] (S6) -- (D9);
# \draw[Cyan, line width=.3mm] (S6) -- (D10);
# \draw[Cyan, line width=.3mm] (S8) -- (D4);
# \draw[Cyan, line width=.3mm] (S8) -- (D5);
# \draw[Cyan, line width=.3mm] (S8) -- (D11);
# \draw[Cyan, line width=.3mm] (S8) -- (D12);
# \draw[Cyan, line width=.3mm] (S9) -- (D13);
# \draw[Cyan, line width=.3mm] (S10) -- (D7);
# \draw[Cyan, line width=.3mm] (S10) -- (D8);
# \draw[Cyan, line width=.3mm] (S10) -- (D14);
# \draw[Cyan, line width=.3mm] (S10) -- (D15);
# \draw[Cyan, line width=.3mm] (S11) -- (D9);
# \draw[Cyan, line width=.3mm] (S11) -- (D16);
# \draw[Cyan, line width=.3mm] (S13) -- (D10);
# \draw[Cyan, line width=.3mm] (S13) -- (D11);
# \draw[Cyan, line width=.3mm] (S13) -- (D17);
# \draw[Cyan, line width=.3mm] (S13) -- (D18);
# \draw[Cyan, line width=.3mm] (S14) -- (D19);
# \draw[Cyan, line width=.3mm] (S15) -- (D12);
# \draw[Cyan, line width=.3mm] (S16) -- (D13);
# \draw[Cyan, line width=.3mm] (S16) -- (D20);
# \draw[Cyan, line width=.3mm] (S17) -- (D14);
# \draw[Cyan, line width=.3mm] (S17) -- (D21);
# \draw[Cyan, line width=.3mm] (S19) -- (D15);
# \draw[Cyan, line width=.3mm] (S19) -- (D22);
# \draw[Cyan, line width=.3mm] (S19) -- (D23);
# \draw[Cyan, line width=.3mm] (S20) -- (D16);
# \draw[Cyan, line width=.3mm] (S20) -- (D17);
# \draw[Cyan, line width=.3mm] (S21) -- (D24);
# \draw[Cyan, line width=.3mm] (S22) -- (D18);
# \draw[Cyan, line width=.3mm] (S22) -- (D25);
# \draw[Cyan, line width=.3mm] (S23) -- (D19);
# \draw[Cyan, line width=.3mm] (S23) -- (D20);
# \draw[Cyan, line width=.3mm] (S23) -- (D26);
# \draw[Cyan, line width=.3mm] (S23) -- (D27);
# \draw[Cyan, line width=.3mm] (S24) -- (D21);
# \draw[Cyan, line width=.3mm] (S24) -- (D22);
# \draw[Cyan, line width=.3mm] (S24) -- (D28);
# \draw[Cyan, line width=.3mm] (S24) -- (D29);
# \draw[Cyan, line width=.3mm] (S26) -- (D23);
# \draw[Cyan, line width=.3mm] (S26) -- (D24);
# \draw[Cyan, line width=.3mm] (S26) -- (D30);
# \draw[Cyan, line width=.3mm] (S26) -- (D31);
# \draw[Cyan, line width=.3mm] (S27) -- (D25);
# \draw[Cyan, line width=.3mm] (S28) -- (D26);
# \draw[Cyan, line width=.3mm] (S28) -- (D32);
# \draw[Cyan, line width=.3mm] (S28) -- (D33);
# \draw[Cyan, line width=.3mm] (S30) -- (D27);
# \draw[Cyan, line width=.3mm] (S30) -- (D34);
# \draw[Cyan, line width=.3mm] (S31) -- (D28);
# \draw[Cyan, line width=.3mm] (S31) -- (D35);
# \draw[Cyan, line width=.3mm] (S32) -- (D36);
# \draw[Cyan, line width=.3mm] (S33) -- (D29);
# \draw[Cyan, line width=.3mm] (S33) -- (D30);
# \draw[Cyan, line width=.3mm] (S34) -- (D37);
# \draw[Cyan, line width=.3mm] (S34) -- (D38);
# \draw[Cyan, line width=.3mm] (S35) -- (D31);
# \draw[Cyan, line width=.3mm] (S35) -- (D32);
# \draw[Cyan, line width=.3mm] (S35) -- (D39);
# \draw[Cyan, line width=.3mm] (S37) -- (D33);
# \draw[Cyan, line width=.3mm] (S37) -- (D34);
# \draw[Cyan, line width=.3mm] (S37) -- (D40);
# \draw[Cyan, line width=.3mm] (S37) -- (D41);
# \draw[Cyan, line width=.3mm] (S38) -- (D35);
# \draw[Cyan, line width=.3mm] (S39) -- (D36);
# \draw[Cyan, line width=.3mm] (S39) -- (D37);
# \draw[Cyan, line width=.3mm] (S39) -- (D43);
# \draw[Cyan, line width=.3mm] (S39) -- (D44);
# \draw[Cyan, line width=.3mm] (S41) -- (D38);
# \draw[Cyan, line width=.3mm] (S41) -- (D45);
# \draw[Cyan, line width=.3mm] (S41) -- (D46);
# \draw[Cyan, line width=.3mm] (S42) -- (D39);
# \draw[Cyan, line width=.3mm] (S42) -- (D40);
# \draw[Cyan, line width=.3mm] (S42) -- (D47);
# \draw[Cyan, line width=.3mm] (S44) -- (D41);
# \draw[Cyan, line width=.3mm] (S44) -- (D48);
# \draw[Cyan, line width=.3mm] (S45) -- (D42);
# \draw[Cyan, line width=.3mm] (S45) -- (D43);
# \draw[Cyan, line width=.3mm] (S46) -- (D44);
# \draw[Cyan, line width=.3mm] (S46) -- (D45);
# \draw[Cyan, line width=.3mm] (S47) -- (D46);
# 9
# % Draw the plaquettes
# \filldraw[fill=black!10, draw=none] (0,0) -- (2,0) -- (2,2) -- (0,2) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,2) -- (2,2) -- (2,4) -- (0,4) -- cycle;
# \filldraw[fill=black!10, draw=none] (0,4) -- (2,4) -- (2,6) -- (0,6) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,6) -- (2,6) -- (2,8) -- (0,8) -- cycle;
# \filldraw[fill=black!10, draw=none] (0,8) -- (2,8) -- (2,10) -- (0,10) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,10) -- (2,10) -- (2,12) -- (0,12) -- cycle;
# \filldraw[fill=black!10, draw=none] (0,12) -- (2,12) -- (2,14) -- (0,14) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,14) -- (2,14) -- (2,16) -- (0,16) -- cycle;
# \filldraw[fill=black!5, draw=none] (2,0) -- (4,0) -- (4,2) -- (2,2) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,2) -- (4,2) -- (4,4) -- (2,4) -- cycle;
# \filldraw[fill=black!5, draw=none] (2,4) -- (4,4) -- (4,6) -- (2,6) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,6) -- (4,6) -- (4,8) -- (2,8) -- cycle;
# \filldraw[fill=black!5, draw=none] (2,8) -- (4,8) -- (4,10) -- (2,10) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,10) -- (4,10) -- (4,12) -- (2,12) -- cycle;
# \filldraw[fill=black!5, draw=none] (2,12) -- (4,12) -- (4,14) -- (2,14) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,14) -- (4,14) -- (4,16) -- (2,16) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,0) -- (6,0) -- (6,2) -- (4,2) -- cycle;
# \filldraw[fill=black!5, draw=none] (4,2) -- (6,2) -- (6,4) -- (4,4) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,4) -- (6,4) -- (6,6) -- (4,6) -- cycle;
# \filldraw[fill=black!5, draw=none] (4,6) -- (6,6) -- (6,8) -- (4,8) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,8) -- (6,8) -- (6,10) -- (4,10) -- cycle;
# \filldraw[fill=black!5, draw=none] (4,10) -- (6,10) -- (6,12) -- (4,12) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,12) -- (6,12) -- (6,14) -- (4,14) -- cycle;
# \filldraw[fill=black!5, draw=none] (4,14) -- (6,14) -- (6,16) -- (4,16) -- cycle;
# \filldraw[fill=black!5, draw=none] (6,0) -- (8,0) -- (8,2) -- (6,2) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,2) -- (8,2) -- (8,4) -- (6,4) -- cycle;
# \filldraw[fill=black!5, draw=none] (6,4) -- (8,4) -- (8,6) -- (6,6) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,6) -- (8,6) -- (8,8) -- (6,8) -- cycle;
# \filldraw[fill=black!5, draw=none] (6,8) -- (8,8) -- (8,10) -- (6,10) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,10) -- (8,10) -- (8,12) -- (6,12) -- cycle;
# \filldraw[fill=black!5, draw=none] (6,12) -- (8,12) -- (8,14) -- (6,14) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,14) -- (8,14) -- (8,16) -- (6,16) -- cycle;
# \filldraw[fill=black!10, draw=none] (8,0) -- (10,0) -- (10,2) -- (8,2) -- cycle;
# \filldraw[fill=black!5, draw=none] (8,2) -- (10,2) -- (10,4) -- (8,4) -- cycle;
# \filldraw[fill=black!10, draw=none] (8,4) -- (10,4) -- (10,6) -- (8,6) -- cycle;
# \filldraw[fill=black!5, draw=none] (8,6) -- (10,6) -- (10,8) -- (8,8) -- cycle;
# \filldraw[fill=black!10, draw=none] (8,8) -- (10,8) -- (10,10) -- (8,10) -- cycle;
# \filldraw[fill=black!5, draw=none] (8,10) -- (10,10) -- (10,12) -- (8,12) -- cycle;
# \filldraw[fill=black!10, draw=none] (8,12) -- (10,12) -- (10,14) -- (8,14) -- cycle;
# \filldraw[fill=black!5, draw=none] (8,14) -- (10,14) -- (10,16) -- (8,16) -- cycle;
# \filldraw[fill=black!5, draw=none] (10,0) -- (12,0) -- (12,2) -- (10,2) -- cycle;
# \filldraw[fill=black!10, draw=none] (10,2) -- (12,2) -- (12,4) -- (10,4) -- cycle;
# \filldraw[fill=black!5, draw=none] (10,4) -- (12,4) -- (12,6) -- (10,6) -- cycle;
# \filldraw[fill=black!10, draw=none] (10,6) -- (12,6) -- (12,8) -- (10,8) -- cycle;
# \filldraw[fill=black!5, draw=none] (10,8) -- (12,8) -- (12,10) -- (10,10) -- cycle;
# \filldraw[fill=black!10, draw=none] (10,10) -- (12,10) -- (12,12) -- (10,12) -- cycle;
# \filldraw[fill=black!5, draw=none] (10,12) -- (12,12) -- (12,14) -- (10,14) -- cycle;
# \filldraw[fill=black!10, draw=none] (10,14) -- (12,14) -- (12,16) -- (10,16) -- cycle;
# \filldraw[fill=black!10, draw=none] (12,0) -- (14,0) -- (14,2) -- (12,2) -- cycle;
# \filldraw[fill=black!5, draw=none] (12,2) -- (14,2) -- (14,4) -- (12,4) -- cycle;
# \filldraw[fill=black!10, draw=none] (12,4) -- (14,4) -- (14,6) -- (12,6) -- cycle;
# \filldraw[fill=black!5, draw=none] (12,6) -- (14,6) -- (14,8) -- (12,8) -- cycle;
# \filldraw[fill=black!10, draw=none] (12,8) -- (14,8) -- (14,10) -- (12,10) -- cycle;
# \filldraw[fill=black!5, draw=none] (12,10) -- (14,10) -- (14,12) -- (12,12) -- cycle;
# \filldraw[fill=black!10, draw=none] (12,12) -- (14,12) -- (14,14) -- (12,14) -- cycle;
# \filldraw[fill=black!5, draw=none] (12,14) -- (14,14) -- (14,16) -- (12,16) -- cycle;
# \filldraw[fill=black!5, draw=none] (14,0) -- (16,0) -- (16,2) -- (14,2) -- cycle;
# \filldraw[fill=black!10, draw=none] (14,2) -- (16,2) -- (16,4) -- (14,4) -- cycle;
# \filldraw[fill=black!5, draw=none] (14,4) -- (16,4) -- (16,6) -- (14,6) -- cycle;
# \filldraw[fill=black!10, draw=none] (14,6) -- (16,6) -- (16,8) -- (14,8) -- cycle;
# \filldraw[fill=black!5, draw=none] (14,8) -- (16,8) -- (16,10) -- (14,10) -- cycle;
# \filldraw[fill=black!10, draw=none] (14,10) -- (16,10) -- (16,12) -- (14,12) -- cycle;
# \filldraw[fill=black!5, draw=none] (14,12) -- (16,12) -- (16,14) -- (14,14) -- cycle;
# \filldraw[fill=black!10, draw=none] (14,14) -- (16,14) -- (16,16) -- (14,16) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,0) -- (0,2) -- (-1,1) -- cycle;
# \filldraw[fill=black!5, draw=none] (16,2) -- (16,4) -- (17,3) -- cycle;
# \filldraw[fill=black!10, draw=none] (2,0) -- (4,0) -- (3,-1) -- cycle;
# \filldraw[fill=black!10, draw=none] (0,16) -- (2,16) -- (1,17) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,4) -- (0,6) -- (-1,5) -- cycle;
# \filldraw[fill=black!5, draw=none] (16,6) -- (16,8) -- (17,7) -- cycle;
# \filldraw[fill=black!10, draw=none] (6,0) -- (8,0) -- (7,-1) -- cycle;
# \filldraw[fill=black!10, draw=none] (4,16) -- (6,16) -- (5,17) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,8) -- (0,10) -- (-1,9) -- cycle;
# \filldraw[fill=black!5, draw=none] (16,10) -- (16,12) -- (17,11) -- cycle;
# \filldraw[fill=black!10, draw=none] (10,0) -- (12,0) -- (11,-1) -- cycle;
# \filldraw[fill=black!10, draw=none] (8,16) -- (10,16) -- (9,17) -- cycle;
# \filldraw[fill=black!5, draw=none] (0,12) -- (0,14) -- (-1,13) -- cycle;
# \filldraw[fill=black!5, draw=none] (16,14) -- (16,16) -- (17,15) -- cycle;
# \filldraw[fill=black!10, draw=none] (14,0) -- (16,0) -- (15,-1) -- cycle;
# \filldraw[fill=black!10, draw=none] (12,16) -- (14,16) -- (13,17) -- cycle;
#
# % Draw the data qubits
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D0) at (0.0,0.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D1) at (2.0,0.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D2) at (4.0,0.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D3) at (6.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D4) at (8.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D5) at (10.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D6) at (12.0,0.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D7) at (14.0,0.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D8) at (16.0,0.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D9) at (0.0,2.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D10) at (2.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D11) at (4.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D12) at (6.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D13) at (8.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D14) at (10.0,2.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D15) at (12.0,2.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D16) at (14.0,2.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D17) at (16.0,2.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D18) at (0.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D19) at (2.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D20) at (4.0,4.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D21) at (6.0,4.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D22) at (8.0,4.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D23) at (10.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D24) at (12.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D25) at (14.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D26) at (16.0,4.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D27) at (0.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D28) at (2.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D29) at (4.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D30) at (6.0,6.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D31) at (8.0,6.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D32) at (10.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D33) at (12.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D34) at (14.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D35) at (16.0,6.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D36) at (0.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D37) at (2.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D38) at (4.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D39) at (6.0,8.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D40) at (8.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D41) at (10.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D42) at (12.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D43) at (14.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D44) at (16.0,8.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D45) at (0.0,10.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D46) at (2.0,10.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D47) at (4.0,10.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D48) at (6.0,10.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D49) at (8.0,10.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D50) at (10.0,10.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D51) at (12.0,10.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D52) at (14.0,10.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D53) at (16.0,10.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D54) at (0.0,12.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D55) at (2.0,12.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D56) at (4.0,12.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D57) at (6.0,12.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D58) at (8.0,12.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D59) at (10.0,12.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D60) at (12.0,12.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D61) at (14.0,12.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D62) at (16.0,12.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D63) at (0.0,14.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D64) at (2.0,14.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D65) at (4.0,14.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D66) at (6.0,14.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D67) at (8.0,14.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D68) at (10.0,14.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D69) at (12.0,14.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D70) at (14.0,14.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D71) at (16.0,14.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D72) at (0.0,16.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D73) at (2.0,16.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D74) at (4.0,16.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D75) at (6.0,16.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D76) at (8.0,16.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D77) at (10.0,16.0) {};
# \node[draw, circle, fill=Cerulean, line width=.5mm, minimum size=5mm] (D78) at (12.0,16.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D79) at (14.0,16.0) {};
# \node[draw, circle, fill=White, line width=.5mm, minimum size=5mm] (D80) at (16.0,16.0) {};
#
# % Draw the syndrome qubits
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S0) at (3.0,-1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S1) at (7.0,-1.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S2) at (11.0,-1.0) {};
# ...
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S50) at (3.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S51) at (5.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S52) at (7.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S53) at (9.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S54) at (11.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S55) at (13.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S56) at (15.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S57) at (17.0,11.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S58) at (-1.0,13.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S59) at (1.0,13.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S60) at (3.0,13.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S61) at (5.0,13.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S62) at (7.0,13.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S63) at (9.0,13.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S64) at (11.0,13.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S65) at (13.0,13.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S66) at (15.0,13.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S67) at (1.0,15.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S68) at (3.0,15.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S69) at (5.0,15.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S70) at (7.0,15.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S71) at (9.0,15.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S72) at (11.0,15.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S73) at (13.0,15.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S74) at (15.0,15.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S75) at (17.0,15.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S76) at (1.0,17.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S77) at (5.0,17.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S78) at (9.0,17.0) {};
# \node[draw, circle, fill=black, line width=.5mm, minimum size=2mm] (S79) at (13.0,17.0) {};
#
# % Draw the x stabilizers
# \draw[red!80, line width=.3mm] (S0) -- (D1);
# \draw[red!80, line width=.3mm] (S0) -- (D2);
# \draw[red!80, line width=.3mm] (S1) -- (D3);
# \draw[red!80, line width=.3mm] (S3) -- (D8);
# \draw[red!80, line width=.3mm] (S5) -- (D0);
# \draw[red!80, line width=.3mm] (S5) -- (D1);
# \draw[red!80, line width=.3mm] (S5) -- (D9);
# \draw[red!80, line width=.3mm] (S5) -- (D10);
# \draw[red!80, line width=.3mm] (S6) -- (D11);
# \draw[red!80, line width=.3mm] (S7) -- (D2);
# \draw[red!80, line width=.3mm] (S7) -- (D3);
# \draw[red!80, line width=.3mm] (S8) -- (D4);
# \draw[red!80, line width=.3mm] (S8) -- (D12);
# \draw[red!80, line width=.3mm] (S8) -- (D13);
# \draw[red!80, line width=.3mm] (S10) -- (D5);
# \draw[red!80, line width=.3mm] (S10) -- (D6);
# \draw[red!80, line width=.3mm] (S10) -- (D14);
# \draw[red!80, line width=.3mm] (S10) -- (D15);
# \draw[red!80, line width=.3mm] (S11) -- (D16);
# \draw[red!80, line width=.3mm] (S12) -- (D7);
# \draw[red!80, line width=.3mm] (S14) -- (D10);
# \draw[red!80, line width=.3mm] (S14) -- (D19);
# \draw[red!80, line width=.3mm] (S14) -- (D20);
# \draw[red!80, line width=.3mm] (S15) -- (D11);
# \draw[red!80, line width=.3mm] (S15) -- (D12);
# \draw[red!80, line width=.3mm] (S15) -- (D21);
# \draw[red!80, line width=.3mm] (S17) -- (D13);
# \draw[red!80, line width=.3mm] (S17) -- (D14);
# \draw[red!80, line width=.3mm] (S17) -- (D22);
# \draw[red!80, line width=.3mm] (S17) -- (D23);
# \draw[red!80, line width=.3mm] (S18) -- (D24);
# \draw[red!80, line width=.3mm] (S19) -- (D15);
# \draw[red!80, line width=.3mm] (S20) -- (D16);
# \draw[red!80, line width=.3mm] (S20) -- (D17);
# \draw[red!80, line width=.3mm] (S20) -- (D25);
# \draw[red!80, line width=.3mm] (S20) -- (D26);
# \draw[red!80, line width=.3mm] (S23) -- (D18);
# \draw[red!80, line width=.3mm] (S23) -- (D19);
# \draw[red!80, line width=.3mm] (S23) -- (D27);
# \draw[red!80, line width=.3mm] (S23) -- (D28);
# \draw[red!80, line width=.3mm] (S25) -- (D20);
# \draw[red!80, line width=.3mm] (S25) -- (D29);
# \draw[red!80, line width=.3mm] (S25) -- (D30);
# \draw[red!80, line width=.3mm] (S26) -- (D21);
# \draw[red!80, line width=.3mm] (S26) -- (D22);
# \draw[red!80, line width=.3mm] (S26) -- (D31);
# \draw[red!80, line width=.3mm] (S28) -- (D23);
# \draw[red!80, line width=.3mm] (S28) -- (D32);
# \draw[red!80, line width=.3mm] (S29) -- (D24);
# \draw[red!80, line width=.3mm] (S29) -- (D25);
# \draw[red!80, line width=.3mm] (S29) -- (D33);
# \draw[red!80, line width=.3mm] (S29) -- (D34);
# \draw[red!80, line width=.3mm] (S32) -- (D28);
# \draw[red!80, line width=.3mm] (S32) -- (D29);
# \draw[red!80, line width=.3mm] (S32) -- (D37);
# \draw[red!80, line width=.3mm] (S32) -- (D38);
# \draw[red!80, line width=.3mm] (S34) -- (D30);
# \draw[red!80, line width=.3mm] (S34) -- (D39);
# \draw[red!80, line width=.3mm] (S35) -- (D31);
# \draw[red!80, line width=.3mm] (S35) -- (D32);
# \draw[red!80, line width=.3mm] (S35) -- (D40);
# \draw[red!80, line width=.3mm] (S36) -- (D33);
# \draw[red!80, line width=.3mm] (S36) -- (D41);
# \draw[red!80, line width=.3mm] (S36) -- (D42);
# \draw[red!80, line width=.3mm] (S38) -- (D34);
# \draw[red!80, line width=.3mm] (S38) -- (D35);
# \draw[red!80, line width=.3mm] (S38) -- (D43);
# \draw[red!80, line width=.3mm] (S38) -- (D44);
# \draw[red!80, line width=.3mm] (S41) -- (D36);
# \draw[red!80, line width=.3mm] (S41) -- (D37);
# \draw[red!80, line width=.3mm] (S41) -- (D45);
# \draw[red!80, line width=.3mm] (S41) -- (D46);
# \draw[red!80, line width=.3mm] (S43) -- (D38);
# \draw[red!80, line width=.3mm] (S43) -- (D39);
# \draw[red!80, line width=.3mm] (S43) -- (D47);
# \draw[red!80, line width=.3mm] (S44) -- (D40);
# \draw[red!80, line width=.3mm] (S44) -- (D48);
# \draw[red!80, line width=.3mm] (S44) -- (D49);
# \draw[red!80, line width=.3mm] (S45) -- (D41);
# \draw[red!80, line width=.3mm] (S46) -- (D50);
# \draw[red!80, line width=.3mm] (S47) -- (D42);
# \draw[red!80, line width=.3mm] (S47) -- (D43);
# \draw[red!80, line width=.3mm] (S47) -- (D51);
# \draw[red!80, line width=.3mm] (S47) -- (D52);
# \draw[red!80, line width=.3mm] (S49) -- (D55);
# \draw[red!80, line width=.3mm] (S50) -- (D46);
# \draw[red!80, line width=.3mm] (S50) -- (D47);
# \draw[red!80, line width=.3mm] (S51) -- (D48);
# \draw[red!80, line width=.3mm] (S51) -- (D56);
# \draw[red!80, line width=.3mm] (S51) -- (D57);
# \draw[red!80, line width=.3mm] (S53) -- (D49);
# \draw[red!80, line width=.3mm] (S53) -- (D50);
# \draw[red!80, line width=.3mm] (S53) -- (D58);
# \draw[red!80, line width=.3mm] (S53) -- (D59);
# \draw[red!80, line width=.3mm] (S54) -- (D51);
# \draw[red!80, line width=.3mm] (S54) -- (D60);
# \draw[red!80, line width=.3mm] (S56) -- (D52);
# \draw[red!80, line width=.3mm] (S56) -- (D53);
# \draw[red!80, line width=.3mm] (S56) -- (D61);
# \draw[red!80, line width=.3mm] (S56) -- (D62);
# \draw[red!80, line width=.3mm] (S59) -- (D54);
# \draw[red!80, line width=.3mm] (S59) -- (D63);
# \draw[red!80, line width=.3mm] (S59) -- (D64);
# \draw[red!80, line width=.3mm] (S60) -- (D55);
# \draw[red!80, line width=.3mm] (S60) -- (D56);
# \draw[red!80, line width=.3mm] (S60) -- (D65);
# \draw[red!80, line width=.3mm] (S62) -- (D57);
# \draw[red!80, line width=.3mm] (S62) -- (D58);
# \draw[red!80, line width=.3mm] (S62) -- (D66);
# \draw[red!80, line width=.3mm] (S62) -- (D67);
# \draw[red!80, line width=.3mm] (S64) -- (D59);
# \draw[red!80, line width=.3mm] (S64) -- (D68);
# \draw[red!80, line width=.3mm] (S64) -- (D69);
# \draw[red!80, line width=.3mm] (S65) -- (D60);
# \draw[red!80, line width=.3mm] (S65) -- (D61);
# \draw[red!80, line width=.3mm] (S65) -- (D70);
# \draw[red!80, line width=.3mm] (S67) -- (D72);
# \draw[red!80, line width=.3mm] (S67) -- (D73);
# \draw[red!80, line width=.3mm] (S68) -- (D64);
# \draw[red!80, line width=.3mm] (S69) -- (D65);
# \draw[red!80, line width=.3mm] (S69) -- (D66);
# \draw[red!80, line width=.3mm] (S69) -- (D74);
# \draw[red!80, line width=.3mm] (S69) -- (D75);
# \draw[red!80, line width=.3mm] (S71) -- (D67);
# \draw[red!80, line width=.3mm] (S71) -- (D68);
# \draw[red!80, line width=.3mm] (S71) -- (D76);
# \draw[red!80, line width=.3mm] (S71) -- (D77);
# \draw[red!80, line width=.3mm] (S73) -- (D69);
# \draw[red!80, line width=.3mm] (S73) -- (D78);
# \draw[red!80, line width=.3mm] (S74) -- (D70);
# \draw[red!80, line width=.3mm] (S74) -- (D71);
# \draw[red!80, line width=.3mm] (S74) -- (D79);
# \draw[red!80, line width=.3mm] (S74) -- (D80);
# \draw[red!80, line width=.3mm] (S79) -- (D79);
#
# % Draw the y stabilizers
#
# % Draw the z stabilizers
# \draw[Cyan, line width=.3mm] (S1) -- (D4);
# \draw[Cyan, line width=.3mm] (S2) -- (D5);
# \draw[Cyan, line width=.3mm] (S2) -- (D6);
# \draw[Cyan, line width=.3mm] (S3) -- (D7);
# \draw[Cyan, line width=.3mm] (S4) -- (D0);
# \draw[Cyan, line width=.3mm] (S4) -- (D9);
# \draw[Cyan, line width=.3mm] (S6) -- (D1);
# \draw[Cyan, line width=.3mm] (S6) -- (D2);
# \draw[Cyan, line width=.3mm] (S6) -- (D10);
# \draw[Cyan, line width=.3mm] (S7) -- (D11);
# \draw[Cyan, line width=.3mm] (S7) -- (D12);
# \draw[Cyan, line width=.3mm] (S8) -- (D3);
# \draw[Cyan, line width=.3mm] (S9) -- (D4);
# \draw[Cyan, line width=.3mm] (S9) -- (D5);
# \draw[Cyan, line width=.3mm] (S9) -- (D13);
# \draw[Cyan, line width=.3mm] (S9) -- (D14);
# \draw[Cyan, line width=.3mm] (S11) -- (D6);
# \draw[Cyan, line width=.3mm] (S11) -- (D7);
# \draw[Cyan, line width=.3mm] (S11) -- (D15);
# \draw[Cyan, line width=.3mm] (S12) -- (D8);
# \draw[Cyan, line width=.3mm] (S12) -- (D16);
# \draw[Cyan, line width=.3mm] (S12) -- (D17);
# \draw[Cyan, line width=.3mm] (S13) -- (D9);
# \draw[Cyan, line width=.3mm] (S13) -- (D10);
# \draw[Cyan, line width=.3mm] (S13) -- (D18);
# \draw[Cyan, line width=.3mm] (S13) -- (D19);
# \draw[Cyan, line width=.3mm] (S14) -- (D11);
# \draw[Cyan, line width=.3mm] (S15) -- (D20);
# \draw[Cyan, line width=.3mm] (S16) -- (D12);
# \draw[Cyan, line width=.3mm] (S16) -- (D13);
# \draw[Cyan, line width=.3mm] (S16) -- (D21);
# \draw[Cyan, line width=.3mm] (S16) -- (D22);
# \draw[Cyan, line width=.3mm] (S18) -- (D14);
# \draw[Cyan, line width=.3mm] (S18) -- (D15);
# \draw[Cyan, line width=.3mm] (S18) -- (D23);
# \draw[Cyan, line width=.3mm] (S19) -- (D16);
# \draw[Cyan, line width=.3mm] (S19) -- (D24);
# \draw[Cyan, line width=.3mm] (S19) -- (D25);
# \draw[Cyan, line width=.3mm] (S21) -- (D17);
# \draw[Cyan, line width=.3mm] (S21) -- (D26);
# \draw[Cyan, line width=.3mm] (S22) -- (D18);
# \draw[Cyan, line width=.3mm] (S22) -- (D27);
# \draw[Cyan, line width=.3mm] (S24) -- (D19);
# \draw[Cyan, line width=.3mm] (S24) -- (D20);
# \draw[Cyan, line width=.3mm] (S24) -- (D28);
# \draw[Cyan, line width=.3mm] (S24) -- (D29);
# \draw[Cyan, line width=.3mm] (S25) -- (D21);
# \draw[Cyan, line width=.3mm] (S26) -- (D30);
# \draw[Cyan, line width=.3mm] (S27) -- (D22);
# \draw[Cyan, line width=.3mm] (S27) -- (D23);
# \draw[Cyan, line width=.3mm] (S27) -- (D31);
# \draw[Cyan, line width=.3mm] (S27) -- (D32);
# \draw[Cyan, line width=.3mm] (S28) -- (D24);
# \draw[Cyan, line width=.3mm] (S28) -- (D33);
# \draw[Cyan, line width=.3mm] (S30) -- (D25);
# \draw[Cyan, line width=.3mm] (S30) -- (D26);
# \draw[Cyan, line width=.3mm] (S30) -- (D34);
# \draw[Cyan, line width=.3mm] (S30) -- (D35);
# \draw[Cyan, line width=.3mm] (S31) -- (D27);
# \draw[Cyan, line width=.3mm] (S31) -- (D28);
# \draw[Cyan, line width=.3mm] (S31) -- (D36);
# \draw[Cyan, line width=.3mm] (S31) -- (D37);
# \draw[Cyan, line width=.3mm] (S33) -- (D29);
# \draw[Cyan, line width=.3mm] (S33) -- (D30);
# \draw[Cyan, line width=.3mm] (S33) -- (D38);
# \draw[Cyan, line width=.3mm] (S33) -- (D39);
# \draw[Cyan, line width=.3mm] (S34) -- (D31);
# \draw[Cyan, line width=.3mm] (S34) -- (D40);
# \draw[Cyan, line width=.3mm] (S35) -- (D41);
# \draw[Cyan, line width=.3mm] (S36) -- (D32);
# \draw[Cyan, line width=.3mm] (S37) -- (D33);
# \draw[Cyan, line width=.3mm] (S37) -- (D34);
# \draw[Cyan, line width=.3mm] (S37) -- (D42);
# \draw[Cyan, line width=.3mm] (S37) -- (D43);
# \draw[Cyan, line width=.3mm] (S39) -- (D35);
# \draw[Cyan, line width=.3mm] (S39) -- (D44);
# \draw[Cyan, line width=.3mm] (S40) -- (D36);
# \draw[Cyan, line width=.3mm] (S40) -- (D45);
# \draw[Cyan, line width=.3mm] (S42) -- (D37);
# \draw[Cyan, line width=.3mm] (S42) -- (D38);
# \draw[Cyan, line width=.3mm] (S42) -- (D46);
# \draw[Cyan, line width=.3mm] (S42) -- (D47);
# \draw[Cyan, line width=.3mm] (S43) -- (D48);
# \draw[Cyan, line width=.3mm] (S44) -- (D39);
# \draw[Cyan, line width=.3mm] (S45) -- (D40);
# \draw[Cyan, line width=.3mm] (S45) -- (D49);
# \draw[Cyan, line width=.3mm] (S45) -- (D50);
# \draw[Cyan, line width=.3mm] (S46) -- (D41);
# \draw[Cyan, line width=.3mm] (S46) -- (D42);
# \draw[Cyan, line width=.3mm] (S46) -- (D51);
# \draw[Cyan, line width=.3mm] (S48) -- (D43);
# \draw[Cyan, line width=.3mm] (S48) -- (D44);
# \draw[Cyan, line width=.3mm] (S48) -- (D52);
# \draw[Cyan, line width=.3mm] (S48) -- (D53);
# \draw[Cyan, line width=.3mm] (S49) -- (D45);
# \draw[Cyan, line width=.3mm] (S49) -- (D46);
# \draw[Cyan, line width=.3mm] (S49) -- (D54);
# \draw[Cyan, line width=.3mm] (S50) -- (D55);
# \draw[Cyan, line width=.3mm] (S50) -- (D56);
# \draw[Cyan, line width=.3mm] (S51) -- (D47);
# \draw[Cyan, line width=.3mm] (S52) -- (D48);
# \draw[Cyan, line width=.3mm] (S52) -- (D49);
# \draw[Cyan, line width=.3mm] (S52) -- (D57);
# \draw[Cyan, line width=.3mm] (S52) -- (D58);
# \draw[Cyan, line width=.3mm] (S54) -- (D50);
# \draw[Cyan, line width=.3mm] (S54) -- (D59);
# \draw[Cyan, line width=.3mm] (S55) -- (D51);
# \draw[Cyan, line width=.3mm] (S55) -- (D52);
# \draw[Cyan, line width=.3mm] (S55) -- (D60);
# \draw[Cyan, line width=.3mm] (S55) -- (D61);
# \draw[Cyan, line width=.3mm] (S57) -- (D53);
# \draw[Cyan, line width=.3mm] (S57) -- (D62);
# \draw[Cyan, line width=.3mm] (S58) -- (D54);
# \draw[Cyan, line width=.3mm] (S58) -- (D63);
# \draw[Cyan, line width=.3mm] (S59) -- (D55);
# \draw[Cyan, line width=.3mm] (S60) -- (D64);
# \draw[Cyan, line width=.3mm] (S61) -- (D56);
# \draw[Cyan, line width=.3mm] (S61) -- (D57);
# \draw[Cyan, line width=.3mm] (S61) -- (D65);
# \draw[Cyan, line width=.3mm] (S61) -- (D66);
# \draw[Cyan, line width=.3mm] (S63) -- (D58);
# \draw[Cyan, line width=.3mm] (S63) -- (D59);
# \draw[Cyan, line width=.3mm] (S63) -- (D67);
# \draw[Cyan, line width=.3mm] (S63) -- (D68);
# \draw[Cyan, line width=.3mm] (S64) -- (D60);
# \draw[Cyan, line width=.3mm] (S65) -- (D69);
# \draw[Cyan, line width=.3mm] (S66) -- (D61);
# \draw[Cyan, line width=.3mm] (S66) -- (D62);
# \draw[Cyan, line width=.3mm] (S66) -- (D70);
# \draw[Cyan, line width=.3mm] (S66) -- (D71);
# \draw[Cyan, line width=.3mm] (S67) -- (D63);
# \draw[Cyan, line width=.3mm] (S67) -- (D64);
# \draw[Cyan, line width=.3mm] (S68) -- (D65);
# \draw[Cyan, line width=.3mm] (S68) -- (D73);
# \draw[Cyan, line width=.3mm] (S68) -- (D74);
# \draw[Cyan, line width=.3mm] (S70) -- (D66);
# \draw[Cyan, line width=.3mm] (S70) -- (D67);
# \draw[Cyan, line width=.3mm] (S70) -- (D75);
# \draw[Cyan, line width=.3mm] (S70) -- (D76);
# \draw[Cyan, line width=.3mm] (S72) -- (D68);
# \draw[Cyan, line width=.3mm] (S72) -- (D69);
# \draw[Cyan, line width=.3mm] (S72) -- (D77);
# \draw[Cyan, line width=.3mm] (S72) -- (D78);
# \draw[Cyan, line width=.3mm] (S73) -- (D70);
# \draw[Cyan, line width=.3mm] (S73) -- (D79);
# \draw[Cyan, line width=.3mm] (S75) -- (D71);
# \draw[Cyan, line width=.3mm] (S75) -- (D80);
# \draw[Cyan, line width=.3mm] (S76) -- (D72);
# \draw[Cyan, line width=.3mm] (S76) -- (D73);
# \draw[Cyan, line width=.3mm] (S77) -- (D74);
# \draw[Cyan, line width=.3mm] (S77) -- (D75);
# \draw[Cyan, line width=.3mm] (S78) -- (D76);
# \draw[Cyan, line width=.3mm] (S78) -- (D77);
# \draw[Cyan, line width=.3mm] (S79) -- (D78);
